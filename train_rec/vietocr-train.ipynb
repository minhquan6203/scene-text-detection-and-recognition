# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# downdata and train

# %%
# !unzip /content/drive/MyDrive/train_rec/data/rec_data_up.zip
# !unzip /content/drive/MyDrive/train_rec/data/train_syn.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_syn/syn_img/15663_ver.jpg
#   inflating: train_syn/syn_img/3490.jpg
#   inflating: train_syn/syn_img/3337.jpg
#   inflating: train_syn/syn_img/9848.jpg
#   inflating: train_syn/syn_img/1054_ver.jpg
#   inflating: train_syn/syn_img/4493_ver.jpg
#   inflating: train_syn/syn_img/18559_ver.jpg
#   inflating: train_syn/syn_img/5755_ver.jpg
#   inflating: train_syn/syn_img/12129.jpg
#   inflating: train_syn/syn_img/4805_ver.jpg
#   inflating: train_syn/syn_img/15485.jpg
#   inflating: train_syn/syn_img/14040.jpg
#   inflating: train_syn/syn_img/12464_ver.jpg
#   inflating: train_syn/syn_img/3750.jpg
#   inflating: train_syn/syn_img/7046.jpg
#   inflating: train_syn/syn_img/9957.jpg
#   inflating: train_syn/syn_img/700.jpg
#   inflating: train_syn/syn_img/18516.jpg
#   inflating: train_syn/syn_img/17599_ver.jpg
#   inflating: train_syn/syn_img/19112.jpg
#   inflating: train_syn/syn_img/9716.jpg
# ...

# %%
# !git clone https://github.com/minhquan6203/scene-text-detection-and-recognition.git

# %%
# !rm -rf /content/train_vietocr
# !rm -rf /content/valid_vietocr

# %%
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 129 kB/s
# ...

# %%
# %cd /content/vietocr
# !python /content/vietocr/setup.py build develop
# Out:
# /content/vietocr
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/config
# copying config/__init__.py -> build/lib/config
# creating build/lib/vietocr
# copying vietocr/train.py -> build/lib/vietocr
# copying vietocr/__init__.py -> build/lib/vietocr
# copying vietocr/predict.py -> build/lib/vietocr
# creating build/lib/vietocr/loader
# copying vietocr/loader/aug.py -> build/lib/vietocr/loader
# copying vietocr/loader/dataloader_v1.py -> build/lib/vietocr/loader
# copying vietocr/loader/__init__.py -> build/lib/vietocr/loader
# copying vietocr/loader/dataloader.py -> build/lib/vietocr/loader
# creating build/lib/vietocr/optim
# copying vietocr/optim/optim.py -> build/lib/vietocr/optim
# copying vietocr/optim/__init__.py -> build/lib/vietocr/optim
# copying vietocr/optim/labelsmoothingloss.py -> build/lib/vietocr/optim
# creating build/lib/vietocr/tool
# copying vietocr/tool/create_dataset.py -> build/lib/vietocr/tool
# ...

# %%
# %cd /content
# !python /content/vietocr/vietocr/train.py --config=/content/vietocr/my_config_vgg_trans.yml
# Out:
# /content
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_BN_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_BN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# 100% 548M/548M [00:02<00:00, 226MB/s]
# load weight
# Create train_vietocr: 100%|█████████████████████████████████| 32000/32000 [00:05<00:00, 5695.21it/s]
# Remove 2 invalid images
# Created dataset with 31997 samples
# ...

# %%
# !mv /content/transformerorc_checkpoint.pth /content/drive/MyDrive/train_rec
# !mv /content/transformerorc_weights.pth /content/drive/MyDrive/train_rec
